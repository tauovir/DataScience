# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-3, 3 ,30)
x
# Out:
# array([-3.        , -2.79310345, -2.5862069 , -2.37931034, -2.17241379,
#        -1.96551724, -1.75862069, -1.55172414, -1.34482759, -1.13793103,
#        -0.93103448, -0.72413793, -0.51724138, -0.31034483, -0.10344828,
#         0.10344828,  0.31034483,  0.51724138,  0.72413793,  0.93103448,
#         1.13793103,  1.34482759,  1.55172414,  1.75862069,  1.96551724,
#         2.17241379,  2.37931034,  2.5862069 ,  2.79310345,  3.        ])

# %%
y = x  * 2
y
# Out:
# array([-6.        , -5.5862069 , -5.17241379, -4.75862069, -4.34482759,
#        -3.93103448, -3.51724138, -3.10344828, -2.68965517, -2.27586207,
#        -1.86206897, -1.44827586, -1.03448276, -0.62068966, -0.20689655,
#         0.20689655,  0.62068966,  1.03448276,  1.44827586,  1.86206897,
#         2.27586207,  2.68965517,  3.10344828,  3.51724138,  3.93103448,
#         4.34482759,  4.75862069,  5.17241379,  5.5862069 ,  6.        ])

# %%
#plt.plot(x, y, color = 'r', symbols = '-')
plt.plot(x, y, 'g2',linewidth=2, markersize=20)
plt.show()

# %%
x1 = np.linspace(-3,3,30)
y1 = x**2
x1.shape
# Out:
# (30,)

# %%
plt.plot(x1,y1,'g.', marker = 3)
plt.show()

# %%
plt.plot(x1, np.sin(x1),'r.')
plt.plot(x1, np.cos(x1),'g-')
plt.plot(x1, -np.sin(x1),'y--')
#plt.plot(x1, np.tan(x1),'b.')


plt.show()
