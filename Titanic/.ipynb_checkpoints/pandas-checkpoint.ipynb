# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('data/train.csv')

# %%
np.random.rand(5,3)
# Out:
# array([[0.29446337, 0.90371804, 0.43883405],
#        [0.05112621, 0.63042246, 0.16200832],
#        [0.29510319, 0.09762547, 0.25387372],
#        [0.34127758, 0.4947802 , 0.35505644],
#        [0.49466604, 0.81258375, 0.27291486]])

# %% [markdown]
# # Viewing/Inspecting Data

# %%
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail(5) # Last n rows of the DataFrame
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.shape # Number of rows and columns
# Out:
# (891, 12)

# %%
data.info() # Index, Datatype and Memory information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
data.describe() # Summary statistics for numerical columns
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data['Pclass'].value_counts(dropna=False) #View unique values and counts
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data['Sex'].value_counts(dropna=False) #View unique values and counts
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data['Sex'] = data['Sex'].apply(lambda x: x + '-Per') # Return Series

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name         Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male-Per  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female-Per  38.0      1
# 2                             Heikkinen, Miss. Laina  female-Per  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female-Per  35.0      1
# 4                           Allen, Mr. William Henry    male-Per  35.0      0
# 5                                   Moran, Mr. James    male-Per   NaN      0
# 6                            McCarthy, Mr. Timothy J    male-Per  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male-Per   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female-Per  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female-Per  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
# Selection

# %%
data['Sex'].head(2) # Returns column with label col as Series
# Out:
# 0      male-Per
# 1    female-Per
# Name: Sex, dtype: object

# %%
data[['Sex','Age']].head(2) # Returns columns as a new DataFrame
# Out:
#           Sex   Age
# 0    male-Per  22.0
# 1  female-Per  38.0

# %%
data.iloc[0] # Selection by position
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                           male-Per
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
data.loc[1] # Selection by index
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                   female-Per
# Age                                                           38
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
data.iloc[0,:] #First row
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                           male-Per
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %% [markdown]
# # Data Cleaning

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name         Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male-Per  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female-Per  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
data.isnull().head(3) # Checks for null Values, Returns Boolean Arrray
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False

# %%
data.notnull().head(3) # Opposite of pd.isnull()
# Out:
#    PassengerId  Survived  Pclass  Name   Sex   Age  SibSp  Parch  Ticket  \
# 0         True      True    True  True  True  True   True   True    True
# 1         True      True    True  True  True  True   True   True    True
# 2         True      True    True  True  True  True   True   True    True
#
#    Fare  Cabin  Embarked
# 0  True  False      True
# 1  True   True      True
# 2  True  False      True

# %%
data1 = data.copy()
data1.shape
# Out:
# (891, 12)

# %%
data1.dropna(inplace = True) # Drop all rows that contain null values

# %%
data1.shape
# Out:
# (183, 12)

# %%
data2 = data.copy()
data2.shape
# Out:
# (891, 12)

# %%
data2.dropna(axis=1, inplace = True) # Drop all columns that contain null values
data2.shape
# Out:
# (891, 9)

# %%
data3 = data.copy()
data3['Age'].fillna(data3['Age'].mean(),inplace = True) # s.fillna(s.mean()), Replace all null values with the mean

# %%
data3['Age'].isnull().sum()
# Out:
# 0

# %%
#s.astype(float)
data['Age'] = data['Age'].astype(float)

# %%
# s.replace(1,'one'),s.replace([2,3],['two', 'three'])
data['Sex'].replace('male-Per', 'male-Per55',inplace = True)
data['Sex'].head(5)
# Out:
# 0    male-Per55
# 1    female-Per
# 2    female-Per
# 3    female-Per
# 4    male-Per55
# Name: Sex, dtype: object

# %%
#df.rename(columns={'old_name': 'new_ name'}) # Selective renaming
data.rename(columns={'PassengerId': 'pass_id'},inplace = True)
data.head(5)
# Out:
#    pass_id  Survived  Pclass  \
# 0        1         0       3
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
#
#                                                 Name         Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris  male-Per55  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female-Per  38.0      1
# 2                             Heikkinen, Miss. Laina  female-Per  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female-Per  35.0      1
# 4                           Allen, Mr. William Henry  male-Per55  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Filter, Sort, and Groupby

# %%
data[data['Age'] >= 30] # Rows where the column col is greater than= 30
# Out:
#      pass_id  Survived  Pclass  \
# 1          2         1       1
# 3          4         1       1
# 4          5         0       3
# 6          7         0       1
# 11        12         1       1
# 13        14         0       3
# 15        16         1       2
# 18        19         0       3
# 20        21         0       2
# 21        22         1       2
# 25        26         1       3
# 30        31         0       1
# 33        34         0       2
# 35        36         0       1
# 40        41         0       3
# 52        53         1       1
# 54        55         0       1
# 61        62         1       1
# 62        63         0       1
# 70        71         0       2
# 74        75         1       3
# 79        80         1       3
# 85        86         1       3
# 92        93         0       1
# 94        95         0       3
# 96        97         0       1
# 98        99         1       2
# 99       100         0       2
# 103      104         0       3
# 104      105         0       3
# ..       ...       ...     ...
# 809      810         1       1
# 811      812         0       3
# 812      813         0       2
# 814      815         0       3
# 817      818         0       2
# 818      819         0       3
# 820      821         1       1
# 822      823         0       1
# 829      830         1       1
# 835      836         1       1
# 838      839         1       3
# 842      843         1       1
# 843      844         0       3
# 845      846         0       3
# 847      848         0       3
# 851      852         0       3
# 854      855         0       2
# 856      857         1       1
# 857      858         1       1
# 860      861         0       3
# 862      863         1       1
# 865      866         1       2
# 867      868         0       1
# 871      872         1       1
# 872      873         0       1
# 873      874         0       3
# 879      880         1       1
# 881      882         0       3
# 885      886         0       3
# 890      891         0       3
#
#                                                   Name         Sex   Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female-Per  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female-Per  35.0
# 4                             Allen, Mr. William Henry  male-Per55  35.0
# 6                              McCarthy, Mr. Timothy J  male-Per55  54.0
# 11                            Bonnell, Miss. Elizabeth  female-Per  58.0
# 13                         Andersson, Mr. Anders Johan  male-Per55  39.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female-Per  55.0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female-Per  31.0
# 20                                Fynney, Mr. Joseph J  male-Per55  35.0
# 21                               Beesley, Mr. Lawrence  male-Per55  34.0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  